# %% [markdown]
# **Decision Tree**
#
# **This Project deals with understanding the working of decision trees.**

# %% [markdown]
# **Author :** Ankush Kale
#
# **Project Name:** Prediction using Decision Tree Algorithm

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# %%
# Load the iris dataset
iris = load_iris()

# %%
# Create a Decision Tree classifier
clf = DecisionTreeClassifier()

# %%
# Train the classifier on the iris dataset
clf.fit(iris.data, iris.target)
# Out:
# DecisionTreeClassifier()

# %%
# Visualize the Decision Tree
plt.figure(figsize=(20,10))
plot_tree(clf, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)
plt.show()

# %%
# Predict the class of a new data point
new_data = [[5.0, 3.5, 1.4, 0.2]]
predicted_class = clf.predict(new_data)

print(predicted_class)
# Out:
# [0]
